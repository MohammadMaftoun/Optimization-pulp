# %%
#At first you should install PuLP;
#PuLP is an LP modeler written in Python.
#PuLP can generate MPS or LP files and call GLPK, COIN-OR CLP/CBC, CPLEX, GUROBI, MOSEK, XPRESS, CHOCO, MIPCL, SCIP to solve linear problems
# !pip install PuLP
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pulp as p

# In this case we want to maximize profit so,Create a LP Maximization problem
Lp_prob = p.LpProblem('Problem', p.LpMaximize)

# Create problem Variables
x = p.LpVariable("x", lowBound = 0) # Create a variable x >= 0
y = p.LpVariable("y", lowBound = 0) # Create a variable y >= 0

# %%
Lp_prob += 6 * x + 8 * y

# Subject to:
Lp_prob += 4 * x + y <= 20
Lp_prob += x + 4 * y <= 40

# %%
# Display the problem
print(Lp_prob)

status = Lp_prob.solve() # Solver
print(p.LpStatus[status]) # The solution status

# Printing the answer
print(p.value(x), '',p.value(y),"" ,p.value(Lp_prob.objective))
# Out:
# Problem:
# MAXIMIZE
# 6*x + 8*y + 0
# SUBJECT TO
# _C1: 4 x + y <= 20
#
# _C2: x + 4 y <= 40
#
# VARIABLES
# x Continuous
# y Continuous
#
# Optimal
# 2.6666667  9.3333333  90.6666666

# %% [markdown]
# ## **With simplex method:**

# %% [markdown]
# ![simplxmax.jpg](data:image/jpeg;base64,...)
